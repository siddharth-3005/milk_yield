# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('milk_yield.csv')

# %%
df.head()
# Out:
#          date  Birth.Date  animal.num  Consumed  Yield  Counsumed.times  \
# 0  04-11-2015  22-02-2006        1010      0.48   9.36                1
# 1  05-11-2015  22-02-2006        1010      5.39  30.06                2
# 2  06-11-2015  22-02-2006        1010      7.03  27.01                4
# 3  07-11-2015  22-02-2006        1010      5.06  24.10                1
# 4  08-11-2015  22-02-2006        1010     11.69  36.41                3
#
#    Total.Duration avg.Duration  DaysInMilk  Conductivity.LF  Conductivity.LR  \
# 0             216         5.41           1             5.32             4.57
# 1             947         8.56           2             6.84             6.31
# 2             811         7.48           3             6.61             6.68
# 3             663        13.08           4             6.93             6.79
# 4             837         8.01           5             6.70             6.77
#
#    Conductivity.RF  Conductivity.RR  lactation  month       age
# 0             0.00             5.21          8     11  9.702854
# 1             6.55             6.45          8     11  9.705594
# 2             6.63             6.66          8     11  9.708333
# 3             6.68             7.04          8     11  9.711073
# 4             6.59             6.71          8     11  9.713813

# %%
df.drop(columns = ['date','Birth.Date','avg.Duration','DaysInMilk','animal.num'],axis = 1,inplace = True)

# %%
df
# Out:
#        Consumed  Yield  Counsumed.times  Total.Duration  Conductivity.LF  \
# 0          0.48   9.36                1             216             5.32
# 1          5.39  30.06                2             947             6.84
# 2          7.03  27.01                4             811             6.61
# 3          5.06  24.10                1             663             6.93
# 4         11.69  36.41                3             837             6.70
# ...         ...    ...              ...             ...              ...
# 37049      5.62  20.01                3             461             6.28
# 37050      5.47  18.38                3             545             6.42
# 37051      5.62  19.44                2             436             6.13
# 37052      6.51  22.46                2             386             6.53
# 37053      2.95   9.77                1             201             5.10
#
#        Conductivity.LR  Conductivity.RF  Conductivity.RR  lactation  month  \
# 0                 4.57             0.00             5.21          8     11
# 1                 6.31             6.55             6.45          8     11
# 2                 6.68             6.63             6.66          8     11
# 3                 6.79             6.68             7.04          8     11
# 4                 6.77             6.59             6.71          8     11
# ...                ...              ...              ...        ...    ...
# 37049             7.64             5.99             6.28          7      7
# 37050             6.31             6.00             5.96          7      7
# 37051             6.55             5.73             6.23          7      7
# 37052             6.55             6.22             6.23          7      7
# 37053             5.90             5.53             5.98          7      7
#
#              age
# 0       9.702854
# 1       9.705594
# 2       9.708333
# 3       9.711073
# 4       9.713813
# ...          ...
# 37049  10.544064
# 37050  10.546804
# 37051  10.549543
# 37052  10.552283
# 37053  10.555023
#
# [37054 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37054 entries, 0 to 37053
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Consumed         37054 non-null  float64
#  1   Yield            37054 non-null  float64
#  2   Counsumed.times  37054 non-null  int64
#  3   Total.Duration   37054 non-null  int64
#  4   Conductivity.LF  36919 non-null  float64
#  5   Conductivity.LR  36655 non-null  float64
#  6   Conductivity.RF  36063 non-null  float64
#  7   Conductivity.RR  36376 non-null  float64
#  8   lactation        37054 non-null  int64
#  9   month            37054 non-null  int64
#  10  age              37054 non-null  float64
# dtypes: float64(7), int64(4)
# memory usage: 3.1 MB

# %%
df.isnull().sum()
# Out:
# Consumed             0
# Yield                0
# Counsumed.times      0
# Total.Duration       0
# Conductivity.LF    135
# Conductivity.LR    399
# Conductivity.RF    991
# Conductivity.RR    678
# lactation            0
# month                0
# age                  0
# dtype: int64

# %%
df.describe()
# Out:
#            Consumed         Yield  Counsumed.times  Total.Duration  \
# count  37054.000000  37054.000000     37054.000000    37054.000000
# mean       6.848691     21.496422         2.266422      621.226102
# std        2.384935      9.511728         1.149405      367.356650
# min        0.020000      0.010000         1.000000        8.000000
# 25%        4.570000     14.510000         2.000000      355.000000
# 50%        7.150000     20.850000         2.000000      557.000000
# 75%        8.737500     27.960000         3.000000      814.000000
# max       12.010000     68.860000        16.000000     2377.000000
#
#        Conductivity.LF  Conductivity.LR  Conductivity.RF  Conductivity.RR  \
# count     36919.000000     36655.000000     36063.000000     36376.000000
# mean          6.405116         6.330619         6.377043         6.357199
# std           1.165134         1.195861         1.066855         1.147420
# min           0.000000         0.000000         0.000000         0.000000
# 25%           6.020000         6.020000         6.000000         6.020000
# 50%           6.420000         6.390000         6.390000         6.390000
# 75%           6.860000         6.800000         6.820000         6.800000
# max          17.520000        16.060000        16.840000        17.360000
#
#           lactation         month           age
# count  37054.000000  37054.000000  37054.000000
# mean       3.021806      5.683327      5.675264
# std        1.626820      3.010467      2.075544
# min        1.000000      1.000000      2.437215
# 25%        2.000000      3.000000      4.204224
# 50%        3.000000      5.000000      5.428995
# 75%        4.000000      7.000000      6.554909
# max        9.000000     12.000000     14.987900

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)
k = imputer.fit_transform(df)
df_new = pd.DataFrame(k,columns = df.columns)
print(df_new)
# Out:
#        Consumed  Yield  Counsumed.times  Total.Duration  Conductivity.LF  \
# 0          0.48   9.36              1.0           216.0             5.32
# 1          5.39  30.06              2.0           947.0             6.84
# 2          7.03  27.01              4.0           811.0             6.61
# 3          5.06  24.10              1.0           663.0             6.93
# 4         11.69  36.41              3.0           837.0             6.70
# ...         ...    ...              ...             ...              ...
# 37049      5.62  20.01              3.0           461.0             6.28
# 37050      5.47  18.38              3.0           545.0             6.42
# 37051      5.62  19.44              2.0           436.0             6.13
# 37052      6.51  22.46              2.0           386.0             6.53
# 37053      2.95   9.77              1.0           201.0             5.10
#
#        Conductivity.LR  Conductivity.RF  Conductivity.RR  lactation  month  \
# 0                 4.57             0.00             5.21        8.0   11.0
# 1                 6.31             6.55             6.45        8.0   11.0
# 2                 6.68             6.63             6.66        8.0   11.0
# 3                 6.79             6.68             7.04        8.0   11.0
# 4                 6.77             6.59             6.71        8.0   11.0
# ...                ...              ...              ...        ...    ...
# 37049             7.64             5.99             6.28        7.0    7.0
# 37050             6.31             6.00             5.96        7.0    7.0
# 37051             6.55             5.73             6.23        7.0    7.0
# 37052             6.55             6.22             6.23        7.0    7.0
# 37053             5.90             5.53             5.98        7.0    7.0
#
#              age
# 0       9.702854
# 1       9.705594
# 2       9.708333
# 3       9.711073
# 4       9.713813
# ...          ...
# 37049  10.544064
# 37050  10.546804
# 37051  10.549543
# 37052  10.552283
# 37053  10.555023
#
# [37054 rows x 11 columns]

# %%
df_new.isnull().sum()
# Out:
# Consumed           0
# Yield              0
# Counsumed.times    0
# Total.Duration     0
# Conductivity.LF    0
# Conductivity.LR    0
# Conductivity.RF    0
# Conductivity.RR    0
# lactation          0
# month              0
# age                0
# dtype: int64

# %%
df_new
# Out:
#        Consumed  Yield  Counsumed.times  Total.Duration  Conductivity.LF  \
# 0          0.48   9.36              1.0           216.0             5.32
# 1          5.39  30.06              2.0           947.0             6.84
# 2          7.03  27.01              4.0           811.0             6.61
# 3          5.06  24.10              1.0           663.0             6.93
# 4         11.69  36.41              3.0           837.0             6.70
# ...         ...    ...              ...             ...              ...
# 37049      5.62  20.01              3.0           461.0             6.28
# 37050      5.47  18.38              3.0           545.0             6.42
# 37051      5.62  19.44              2.0           436.0             6.13
# 37052      6.51  22.46              2.0           386.0             6.53
# 37053      2.95   9.77              1.0           201.0             5.10
#
#        Conductivity.LR  Conductivity.RF  Conductivity.RR  lactation  month  \
# 0                 4.57             0.00             5.21        8.0   11.0
# 1                 6.31             6.55             6.45        8.0   11.0
# 2                 6.68             6.63             6.66        8.0   11.0
# 3                 6.79             6.68             7.04        8.0   11.0
# 4                 6.77             6.59             6.71        8.0   11.0
# ...                ...              ...              ...        ...    ...
# 37049             7.64             5.99             6.28        7.0    7.0
# 37050             6.31             6.00             5.96        7.0    7.0
# 37051             6.55             5.73             6.23        7.0    7.0
# 37052             6.55             6.22             6.23        7.0    7.0
# 37053             5.90             5.53             5.98        7.0    7.0
#
#              age
# 0       9.702854
# 1       9.705594
# 2       9.708333
# 3       9.711073
# 4       9.713813
# ...          ...
# 37049  10.544064
# 37050  10.546804
# 37051  10.549543
# 37052  10.552283
# 37053  10.555023
#
# [37054 rows x 11 columns]

# %%
df_new[['Counsumed.times','Total.Duration','lactation','month']]  = df_new[['Counsumed.times','Total.Duration','lactation','month']].astype('int')

# %%
df_new.dtypes
# Out:
# Consumed           float64
# Yield              float64
# Counsumed.times      int32
# Total.Duration       int32
# Conductivity.LF    float64
# Conductivity.LR    float64
# Conductivity.RF    float64
# Conductivity.RR    float64
# lactation            int32
# month                int32
# age                float64
# dtype: object

# %%
x = df_new.drop('Yield',axis = 1)
y = df_new['Yield']

# %%
from sklearn.model_selection import train_test_split
x_train_1,x_test_1,y_train_1,y_test_1 = train_test_split(x,y,train_size = 0.70,random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lr = LinearRegression()
model_base = lr.fit(x_train_1,y_train_1)
pred_base = model_base.predict(x_test_1)
print('rmse of base model is',np.sqrt(mean_squared_error(y_test_1,pred_base)))
# Out:
# rmse of base model is 6.163612239263955

# %%
df_copy = df_new.copy(deep = True)

# %%
df_copy
# Out:
#        Consumed  Yield  Counsumed.times  Total.Duration  Conductivity.LF  \
# 0          0.48   9.36                1             216             5.32
# 1          5.39  30.06                2             947             6.84
# 2          7.03  27.01                4             811             6.61
# 3          5.06  24.10                1             663             6.93
# 4         11.69  36.41                3             837             6.70
# ...         ...    ...              ...             ...              ...
# 37049      5.62  20.01                3             461             6.28
# 37050      5.47  18.38                3             545             6.42
# 37051      5.62  19.44                2             436             6.13
# 37052      6.51  22.46                2             386             6.53
# 37053      2.95   9.77                1             201             5.10
#
#        Conductivity.LR  Conductivity.RF  Conductivity.RR  lactation  month  \
# 0                 4.57             0.00             5.21          8     11
# 1                 6.31             6.55             6.45          8     11
# 2                 6.68             6.63             6.66          8     11
# 3                 6.79             6.68             7.04          8     11
# 4                 6.77             6.59             6.71          8     11
# ...                ...              ...              ...        ...    ...
# 37049             7.64             5.99             6.28          7      7
# 37050             6.31             6.00             5.96          7      7
# 37051             6.55             5.73             6.23          7      7
# 37052             6.55             6.22             6.23          7      7
# 37053             5.90             5.53             5.98          7      7
#
#              age
# 0       9.702854
# 1       9.705594
# 2       9.708333
# 3       9.711073
# 4       9.713813
# ...          ...
# 37049  10.544064
# 37050  10.546804
# 37051  10.549543
# 37052  10.552283
# 37053  10.555023
#
# [37054 rows x 11 columns]

# %%
bins = [2,5,8,11,17]
df_copy['age'] = pd.cut(df_copy['age'],bins = bins,labels = ['Young_adult','mid_adult','senior_adult','mature_adult'])

# %%
df_copy
# Out:
#        Consumed  Yield  Counsumed.times  Total.Duration  Conductivity.LF  \
# 0          0.48   9.36                1             216             5.32
# 1          5.39  30.06                2             947             6.84
# 2          7.03  27.01                4             811             6.61
# 3          5.06  24.10                1             663             6.93
# 4         11.69  36.41                3             837             6.70
# ...         ...    ...              ...             ...              ...
# 37049      5.62  20.01                3             461             6.28
# 37050      5.47  18.38                3             545             6.42
# 37051      5.62  19.44                2             436             6.13
# 37052      6.51  22.46                2             386             6.53
# 37053      2.95   9.77                1             201             5.10
#
#        Conductivity.LR  Conductivity.RF  Conductivity.RR  lactation  month  \
# 0                 4.57             0.00             5.21          8     11
# 1                 6.31             6.55             6.45          8     11
# 2                 6.68             6.63             6.66          8     11
# 3                 6.79             6.68             7.04          8     11
# 4                 6.77             6.59             6.71          8     11
# ...                ...              ...              ...        ...    ...
# 37049             7.64             5.99             6.28          7      7
# 37050             6.31             6.00             5.96          7      7
# 37051             6.55             5.73             6.23          7      7
# 37052             6.55             6.22             6.23          7      7
# 37053             5.90             5.53             5.98          7      7
#
#                 age
# 0      senior_adult
# 1      senior_adult
# 2      senior_adult
# 3      senior_adult
# 4      senior_adult
# ...             ...
# 37049  senior_adult
# 37050  senior_adult
# 37051  senior_adult
# 37052  senior_adult
# 37053  senior_adult
#
# [37054 rows x 11 columns]

# %%
bins = [0,3,6,9]
df_copy['lactation_new']=pd.cut(df_copy['lactation'],bins = bins,labels = ['early','mid','late'])

# %%
bins = [0,4,8,12,17]
df_copy['Counsumed.times_new']=pd.cut(df_copy['Counsumed.times'],bins = bins, labels = ['less','mid','average','late'])

# %%
df_copy
# Out:
#        Consumed  Yield  Counsumed.times  Total.Duration  Conductivity.LF  \
# 0          0.48   9.36                1             216             5.32
# 1          5.39  30.06                2             947             6.84
# 2          7.03  27.01                4             811             6.61
# 3          5.06  24.10                1             663             6.93
# 4         11.69  36.41                3             837             6.70
# ...         ...    ...              ...             ...              ...
# 37049      5.62  20.01                3             461             6.28
# 37050      5.47  18.38                3             545             6.42
# 37051      5.62  19.44                2             436             6.13
# 37052      6.51  22.46                2             386             6.53
# 37053      2.95   9.77                1             201             5.10
#
#        Conductivity.LR  Conductivity.RF  Conductivity.RR  lactation  month  \
# 0                 4.57             0.00             5.21          8     11
# 1                 6.31             6.55             6.45          8     11
# 2                 6.68             6.63             6.66          8     11
# 3                 6.79             6.68             7.04          8     11
# 4                 6.77             6.59             6.71          8     11
# ...                ...              ...              ...        ...    ...
# 37049             7.64             5.99             6.28          7      7
# 37050             6.31             6.00             5.96          7      7
# 37051             6.55             5.73             6.23          7      7
# 37052             6.55             6.22             6.23          7      7
# 37053             5.90             5.53             5.98          7      7
#
#                 age lactation_new Counsumed.times_new
# 0      senior_adult          late                less
# 1      senior_adult          late                less
# 2      senior_adult          late                less
# 3      senior_adult          late                less
# 4      senior_adult          late                less
# ...             ...           ...                 ...
# 37049  senior_adult          late                less
# 37050  senior_adult          late                less
# 37051  senior_adult          late                less
# 37052  senior_adult          late                less
# 37053  senior_adult          late                less
#
# [37054 rows x 13 columns]

# %%
bins = [0,3,6,9,12]
df_copy['month']=pd.cut(df_copy['month'],bins = bins, labels = ['spring','summer','autumn','winter'])

# %%
df_copy.drop(['Counsumed.times','lactation'],axis=1,inplace = True)

# %%
dummy_1=pd.get_dummies(df_copy[['age','lactation_new','Counsumed.times_new','month']])

# %%
df_copy.drop(['age','lactation_new','Counsumed.times_new','month'],axis = 1,inplace = True)

# %%
df_copy = pd.concat([df_copy,dummy_1],axis = 1)

# %%
df_copy
# Out:
#        Consumed  Yield  Total.Duration  Conductivity.LF  Conductivity.LR  \
# 0          0.48   9.36             216             5.32             4.57
# 1          5.39  30.06             947             6.84             6.31
# 2          7.03  27.01             811             6.61             6.68
# 3          5.06  24.10             663             6.93             6.79
# 4         11.69  36.41             837             6.70             6.77
# ...         ...    ...             ...              ...              ...
# 37049      5.62  20.01             461             6.28             7.64
# 37050      5.47  18.38             545             6.42             6.31
# 37051      5.62  19.44             436             6.13             6.55
# 37052      6.51  22.46             386             6.53             6.55
# 37053      2.95   9.77             201             5.10             5.90
#
#        Conductivity.RF  Conductivity.RR  age_Young_adult  age_mid_adult  \
# 0                 0.00             5.21                0              0
# 1                 6.55             6.45                0              0
# 2                 6.63             6.66                0              0
# 3                 6.68             7.04                0              0
# 4                 6.59             6.71                0              0
# ...                ...              ...              ...            ...
# 37049             5.99             6.28                0              0
# 37050             6.00             5.96                0              0
# 37051             5.73             6.23                0              0
# 37052             6.22             6.23                0              0
# 37053             5.53             5.98                0              0
#
#        age_senior_adult  ...  lactation_new_mid  lactation_new_late  \
# 0                     1  ...                  0                   1
# 1                     1  ...                  0                   1
# 2                     1  ...                  0                   1
# 3                     1  ...                  0                   1
# 4                     1  ...                  0                   1
# ...                 ...  ...                ...                 ...
# 37049                 1  ...                  0                   1
# 37050                 1  ...                  0                   1
# 37051                 1  ...                  0                   1
# 37052                 1  ...                  0                   1
# 37053                 1  ...                  0                   1
#
#        Counsumed.times_new_less  Counsumed.times_new_mid  \
# 0                             1                        0
# 1                             1                        0
# 2                             1                        0
# 3                             1                        0
# 4                             1                        0
# ...                         ...                      ...
# 37049                         1                        0
# 37050                         1                        0
# 37051                         1                        0
# 37052                         1                        0
# 37053                         1                        0
#
#        Counsumed.times_new_average  Counsumed.times_new_late  month_spring  \
# 0                                0                         0             0
# 1                                0                         0             0
# 2                                0                         0             0
# 3                                0                         0             0
# 4                                0                         0             0
# ...                            ...                       ...           ...
# 37049                            0                         0             0
# 37050                            0                         0             0
# 37051                            0                         0             0
# 37052                            0                         0             0
# 37053                            0                         0             0
#
#        month_summer  month_autumn  month_winter
# 0                 0             0             1
# 1                 0             0             1
# 2                 0             0             1
# 3                 0             0             1
# 4                 0             0             1
# ...             ...           ...           ...
# 37049             0             1             0
# 37050             0             1             0
# 37051             0             1             0
# 37052             0             1             0
# 37053             0             1             0
#
# [37054 rows x 22 columns]

# %%
x = df_copy.drop('Yield',axis = 1)
y = df_copy['Yield']

# %%
from sklearn.model_selection import train_test_split
x_train_2,x_test_2,y_train_2,y_test_2 = train_test_split(x,y,train_size = 0.70,random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lr = LinearRegression()
model_base_1 = lr.fit(x_train_2,y_train_2)
pred_base_1 = model_base_1.predict(x_test_2)
print('rmse of base model is',np.sqrt(mean_squared_error(y_test_2,pred_base_1)))
# Out:
# rmse of base model is 6.1702657994146906

# %%
import mlxtend.feature_selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

lr = LinearRegression()

sfs_forward= SequentialFeatureSelector(estimator = lr,
                                           k_features=5,
                                           forward = True,
                                           verbose=2,
                                           scoring = "neg_root_mean_squared_error")

# %%
sfs_forward.fit(x_train_1,y_train_1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
#
# [2023-08-25 07:52:59] Features: 1/5 -- score: -7.192373022847955[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.1s finished
#
# [2023-08-25 07:52:59] Features: 2/5 -- score: -6.529588834965057[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:00] Features: 3/5 -- score: -6.385151368820372[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:00] Features: 4/5 -- score: -6.329405122397749[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:00] Features: 5/5 -- score: -6.271275806315602
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(5, 5),
#                           scoring='neg_root_mean_squared_error', verbose=2)

# %%
features = list(sfs_forward.k_feature_names_)

# %%
x_train_3 = x_train_1.loc[:,features]
x_test_3 = x_test_1.loc[:,features]

# %%
lr = LinearRegression()
model_3 = lr.fit(x_train_3,y_train_1)
pred_base_2 = model_3.predict(x_test_3)
print('rmse of base model is',np.sqrt(mean_squared_error(y_test_1,pred_base_2)))
# Out:
# rmse of base model is 6.216646967073974

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

lr = LinearRegression()

sfs_forward_best= SequentialFeatureSelector(estimator = lr,
                                           k_features='best',
                                           forward = True,
                                           verbose=2,
                                           scoring = "neg_root_mean_squared_error")

# %%
sfs_forward_best.fit(x_train_1,y_train_1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:00] Features: 1/10 -- score: -7.192373022847955[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:00] Features: 2/10 -- score: -6.529588834965057[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:00] Features: 3/10 -- score: -6.385151368820372[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:01] Features: 4/10 -- score: -6.329405122397749[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:01] Features: 5/10 -- score: -6.271275806315602[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:01] Features: 6/10 -- score: -6.243906741118117[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:01] Features: 7/10 -- score: -6.231266792501475[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:01] Features: 8/10 -- score: -6.2224611158432035[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:01] Features: 9/10 -- score: -6.217267710755149[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:01] Features: 10/10 -- score: -6.213527747152888
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(1, 10),
#                           scoring='neg_root_mean_squared_error', verbose=2)

# %%
features = list(sfs_forward_best.k_feature_names_)

# %%
x_train_4 = x_train_1.loc[:,features]
x_test_4 = x_test_1.loc[:,features]

# %%
lr = LinearRegression()
model_3 = lr.fit(x_train_4,y_train_1)
pred_base_3 = model_3.predict(x_test_4)
print('rmse of base model is',np.sqrt(mean_squared_error(y_test_1,pred_base_3)))
# Out:
# rmse of base model is 6.163612239263955

# %%
sfs_backward= SequentialFeatureSelector(estimator = lr,
                                           k_features=5,
                                           forward = False,
                                           verbose=2,
                                           scoring = "neg_root_mean_squared_error")

# %%
sfs_backward.fit(x_train_1,y_train_1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.3s finished
#
# [2023-08-25 07:53:02] Features: 9/5 -- score: -6.217267710755149[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.2s finished
#
# [2023-08-25 07:53:02] Features: 8/5 -- score: -6.2224611158432035[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:02] Features: 7/5 -- score: -6.231266792501475[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:03] Features: 6/5 -- score: -6.243906741118117[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:03] Features: 5/5 -- score: -6.271275806315602
# SequentialFeatureSelector(estimator=LinearRegression(), forward=False,
#                           k_features=(5, 5),
#                           scoring='neg_root_mean_squared_error', verbose=2)

# %%
features = list(sfs_backward.k_feature_names_)

# %%
x_train_5 = x_train_1.loc[:,features]
x_test_5 = x_test_1.loc[:,features]

# %%
lr = LinearRegression()
model_4 = lr.fit(x_train_5,y_train_1)
pred_base_4 = model_4.predict(x_test_5)
print('rmse of base model is',np.sqrt(mean_squared_error(y_test_1,pred_base_4)))
# Out:
# rmse of base model is 6.216646967073974

# %%
lr = LinearRegression()

sfs_backward_best= SequentialFeatureSelector(estimator = lr,
                                           k_features='best',
                                           forward = False,
                                           verbose=2,
                                           scoring = "neg_root_mean_squared_error")

# %%
sfs_backward_best.fit(x_train_1,y_train_1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.3s finished
#
# [2023-08-25 07:53:03] Features: 9/1 -- score: -6.217267710755149[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.2s finished
#
# [2023-08-25 07:53:03] Features: 8/1 -- score: -6.2224611158432035[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:04] Features: 7/1 -- score: -6.231266792501475[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:04] Features: 6/1 -- score: -6.243906741118117[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.1s finished
#
# [2023-08-25 07:53:04] Features: 5/1 -- score: -6.271275806315602[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:04] Features: 4/1 -- score: -6.329405122397749[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:04] Features: 3/1 -- score: -6.385151368820372[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:04] Features: 2/1 -- score: -6.529588834965057[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s finished
#
# [2023-08-25 07:53:04] Features: 1/1 -- score: -7.192373022847955
# SequentialFeatureSelector(estimator=LinearRegression(), forward=False,
#                           k_features=(1, 10),
#                           scoring='neg_root_mean_squared_error', verbose=2)

# %%
features = list(sfs_backward_best.k_feature_names_)

# %%
x_train_6 = x_train_1.loc[:,features]
x_test_6 = x_test_1.loc[:,features]

# %%
lr = LinearRegression()
model_5 = lr.fit(x_train_6,y_train_1)
pred_base_5 = model_5.predict(x_test_6)
print('rmse of base model is',np.sqrt(mean_squared_error(y_test_1,pred_base_5)))
# Out:
# rmse of base model is 6.163612239263955

# %%
from sklearn.feature_selection import RFE
lr = LinearRegression()

# %%
rfe = RFE(estimator = lr,
         n_features_to_select = 5)

# %%
rfe.fit(x_train_1,y_train_1)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
pd.DataFrame(rfe.ranking_,index = x_train_1.columns)
# Out:
#                  0
# Consumed         1
# Counsumed.times  1
# Total.Duration   6
# Conductivity.LF  5
# Conductivity.LR  1
# Conductivity.RF  3
# Conductivity.RR  1
# lactation        1
# month            4
# age              2

# %%
feature_index = pd.Series(rfe.ranking_,index = x_train_1.columns).sort_values(ascending = False)

# %%
impfeature_rfe = feature_index[feature_index==1].index

# %%
impfeature_rfe
# Out:
# Index(['Consumed', 'Counsumed.times', 'Conductivity.LR', 'Conductivity.RR',
#        'lactation'],
#       dtype='object')

# %%
rfe_train = x_train_1.loc[:,impfeature_rfe]
rfe_test = x_test_1.loc[:,impfeature_rfe]

# %%
lr = LinearRegression()

model_6 = lr.fit(rfe_train,y_train_1)
pred_6 = model_6.predict(rfe_test)
rfe_rmse = np.sqrt(mean_squared_error(y_test_1,pred_6))
print(rfe_rmse)
# Out:
# 6.933563246054707

# %%
num = df_new[['Consumed','Yield','Total.Duration','Conductivity.LF','Conductivity.LR','Conductivity.RF','Conductivity.RR','age']].columns.to_list()

# %%
for i in num:
    sns.distplot(df_new[i])
    plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import PowerTransformer
pp = PowerTransformer()
for i in num:
    df_new[i] = pp.fit_transform(df_new[[i]])

# %%
x = df_new.drop('Yield',axis = 1)
y = df_new['Yield']

# %%
from sklearn.model_selection import train_test_split
x_train_p,x_test_p,y_train_p,y_test_p = train_test_split(x,y,train_size = 0.70,random_state = 100)

# %%
lr = LinearRegression()

model_p = lr.fit(x_train_p,y_train_p)
pred_p = model_p.predict(x_test_p)
print('rmse is',np.sqrt(mean_squared_error(y_test_p,pred_p)))
# Out:
# rmse is 0.6339082539186892
